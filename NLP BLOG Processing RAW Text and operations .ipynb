# %%
#we can see some text operations and tokenizations sample

# %%
from __future__ import division 
import nltk,re,pprint

# %%
#accessing text from web 

from urllib.request import urlopen
url = "http://www.gutenberg.org/files/58700/58700-0.txt"
raw = urlopen(url).read().decode('utf-8')

# %%
type(raw)
# Out:
# str

# %%
raw
# Out:
# '\ufeffThe Project Gutenberg EBook of Crimes and Punishments, by James Anson Farrer\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever.  You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this eBook or online at\r\nwww.gutenberg.org.  If you are not located in the United States, you\'ll\r\nhave to check the laws of the country where you are located before using\r\nthis ebook.\r\n\r\n\r\n\r\nTitle: Crimes and Punishments\r\n       Including a New Translation of Beccaria\'s \'Dei Delitti e delle Pene\'\r\n\r\nAuthor: James Anson Farrer\r\n\r\nRelease Date: January 15, 2019 [EBook #58700]\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK CRIMES AND PUNISHMENTS ***\r\n\r\n\r\n\r\n\r\nProduced by Turgut Dincer and the Online Distributed\r\nProofreading Team 
# ...

# %%
tokens = nltk.word_tokenize(raw)

# %%
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 70986

# %%
tokens[:25]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Crimes',
#  'and',
#  'Punishments',
#  ',',
#  'by',
#  'James',
#  'Anson',
#  'Farrer',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United']

# %%
text = nltk.Text(tokens)

# %%
text
# Out:
# <Text: ﻿The Project Gutenberg EBook of Crimes and Punishments...>

# %%
type(text)
# Out:
# nltk.text.Text

# %%
text[30:988]
# Out:
# ['of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States',
#  ',',
#  "you'll",
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
#  'located',
#  'before',
#  'using',
#  'this',
#  'ebook',
#  '.',
#  'Title',
#  ':',
#  'Crimes',
#  'and',
#  'Punishments',
#  'Including',
#  'a',
#  'New',
#  'Translation',
#  'of',
#  'Beccaria',
#  "'s",
#  "'Dei",
#  'Delitti',
#  'e',
#  'delle',
#  "Pene'",
#  'Author',
#  ':',
# ...

# %%
text.collocations()
# Out:
# Project Gutenberg-tm; Project Gutenberg; capital punishment; United
# States; penal servitude; Literary Archive; Gutenberg-tm electronic;
# electronic works; Gutenberg Literary; Archive Foundation; per cent;
# Dei Delitti; Pietro Verri; penal laws; criminal law; set forth; Lord
# Ellenborough; electronic work; Gutenberg-tm License; one another

# %%
raw.find("capital")
# Out:
# 5369

# %%
raw.rfind("capital")
# Out:
# 256434

# %%
#reading html files and cleaning them

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = urlopen(url).read()

# %%
html[:50]
# Out:
# b'<!doctype html public "-//W3C//DTD HTML 4.0 Transi'

# %%
raw = nltk.clean_html(html)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-19-02d9735a8c43> in <module>()
# ----> 1 raw = nltk.clean_html(html)
#
# ~\AppData\Roaming\Python\Python36\site-packages\nltk\util.py in clean_html(html)
#     354
#     355 def clean_html(html):
# --> 356     raise NotImplementedError ("To remove HTML markup, use BeautifulSoup's get_text() function")
#     357
#     358 def clean_url(url):
#
# NotImplementedError: To remove HTML markup, use BeautifulSoup's get_text() function

# %%
#since not implemented in newer version of nltk , we can use BS4

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html)
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python36\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file D:\Anaconda\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
text = soup.get_text()
print(text)
# Out:
# BBC NEWS | Health | Blondes 'to die out in 200 years'
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NEWS
#   SPORT
#   WEATHER
#   WORLD SERVICE
#
#   A-Z INDEX
#
#   SEARCH
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      You are in: Health
#
#
#
#
#
#
#
#
#
#
#
#
#
# News Front Page
#
#
#
#
#
# Africa
#
#
# Americas
#
#
# Asia-Pacific
#
#
# Europe
#
#
# Middle East
#
#
# South Asia
#
#
# UK
#
#
# Business
#
#
# Entertainment
#
#
# Science/Nature
#
#
# Technology
#
#
# Health
#
#
# Medical notes
#
#
# -------------
#
#
# Talking Point
#
#
# -------------
#
#
# Country Profiles
#
#
# In Depth
#
#
# -------------
#
#
# Programmes
#
#
# -------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SERVICES
#
#
#
#
#
#
#
# Daily E-mail
#
#
#
#
#
#
#
# News Ticker
#
#
#
#
#
#
#
# Mobile/PDAs
#
#
#
#
#
#
# -------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Text Only
#
#
#
#
#
#
#
#
# Feedback
#
#
#
#
#
#
#
# Help
# ...

# %%
tokens = nltk.word_tokenize(text)

# %%
tokens
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH',
#  'You',
#  'are',
#  'in',
#  ':',
#  'Health',
#  'News',
#  'Front',
#  'Page',
#  'Africa',
#  'Americas',
#  'Asia-Pacific',
#  'Europe',
#  'Middle',
#  'East',
#  'South',
#  'Asia',
#  'UK',
#  'Business',
#  'Entertainment',
#  'Science/Nature',
#  'Technology',
#  'Health',
#  'Medical',
#  'notes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Talking',
#  'Point',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Country',
#  'Profiles',
#  'In',
#  'Depth',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Programmes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'SERVICES',
#  'Daily',
#  'E-mail',
#  'News',
#  'Ticker',
#  'Mobile/PDAs',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
tokens = tokens[96:500]

# %%
text = nltk.Text(tokens)

# %%
print(text)
# Out:
# <Text: EDITIONS Change to UK Friday , 27 September...>

# %%
text.concordance('blonde')
# Out:
# Displaying 4 of 4 matches:
# erts in Germany suggests people with blonde hair are an endangered species and w
# chers predict the last truly natural blonde will be born in Finland - the countr
#  two centuries . The problem is that blonde hair is caused by a recessive gene .
#  gene . In order for a child to have blonde hair , it must have the gene on both

# %%
text.concordance('gene')
# Out:
# Displaying 6 of 6 matches:
# they say too few people now carry the gene for blondes to last beyond the next t
#  blonde hair is caused by a recessive gene . In order for a child to have blonde
# o have blonde hair , it must have the gene on both sides of the family in the gr
# here is a disadvantage of having that gene or by chance . They do n't disappear
# ndes would disappear is if having the gene was a disadvantage and I do not think
# mer's Polio campaign launched in Iraq Gene defect explains high blood pressure B

# %%
import feedparser #lets see some contents on feed parser

# %%
llog = feedparser.parse("https://languagelog.ldc.upenn.edu/nll/?feed=atom")

# %%
llog['feed']['title']
# Out:
# 'Language Log'

# %%
llog
# Out:
# {'bozo': 0,
#  'encoding': 'UTF-8',
#  'entries': [{'author': 'Victor Mair',
#    'author_detail': {'href': 'https://www.sas.upenn.edu/ealc/mair',
#     'name': 'Victor Mair'},
#    'authors': [{'href': 'https://www.sas.upenn.edu/ealc/mair',
#      'name': 'Victor Mair'}],
#    'content': [{'base': 'https://languagelog.ldc.upenn.edu/nll/?p=45606',
#      'language': 'en-US',
#      'type': 'text/html',
# ...

# %%
len(llog.entries)
# Out:
# 13

# %%
post = llog.entries[2]

# %%
post
# Out:
# {'author': 'Victor Mair',
#  'author_detail': {'href': 'https://www.sas.upenn.edu/ealc/mair',
#   'name': 'Victor Mair'},
#  'authors': [{'href': 'https://www.sas.upenn.edu/ealc/mair',
#    'name': 'Victor Mair'}],
#  'content': [{'base': 'https://languagelog.ldc.upenn.edu/nll/?p=45581',
#    'language': 'en-US',
#    'type': 'text/html',
# ...

# %%
post.title
# Out:
# 'The semiotics of an East Asian hand gesture'

# %%
content =post.content[0].value

# %%
content
# Out:
# '<p>These days people make all sorts of public and private hand gestures to convey a wide variety of information.\xa0 Innocent though they may seem, for various reasons many of them become controversial (e.g., the sign for "OK", which has recently been classified by some organizations as a symbol of hate).</p>\n<p>These students at a university in China are making the sign of bǐxīn 比心.\xa0 According to their professor, it means "love you" or "give you my heart".</p>\n<p align="center"><a href="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin1.jpg"><img title="Click to embiggen" src="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin1.jpg" alt="" width="475" /></a><span id="more-45581"></span></p>\n<p>Here\'s the same photo with the many heart gestures outlined in red:</p>\n<p align="center"><a href="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin2.jpg"><img title="Click to embiggen" src="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin2.jpg" alt="" width="475" /></a></p>\n<p>And here\
# ...

# %%
content[:70]
# Out:
# '<p>These days people make all sorts of public and private hand gesture'

# %%
clean_content =  BeautifulSoup(content,"lxml")

# %%
clean_content
# Out:
# <html><body><p>These days people make all sorts of public and private hand gestures to convey a wide variety of information.  Innocent though they may seem, for various reasons many of them become controversial (e.g., the sign for "OK", which has recently been classified by some organizations as a symbol of hate).</p>
# <p>These students at a university in China are making the sign of bǐxīn 比心.  According to their professor, it means "love you" or "give you my heart".</p>
# <p align="center"><a href="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin1.jpg"><img alt="" src="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin1.jpg" title="Click to embiggen" width="475"/></a><span id="more-45581"></span></p>
# <p>Here's the same photo with the many heart gestures outlined in red:</p>
# <p align="center"><a href="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin2.jpg"><img alt="" src="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin2.jpg" title="Click to embiggen" width="475"/></a></p>
# ...

# %%
type(clean_content)
# Out:
# bs4.BeautifulSoup

# %%
clean_content = str(clean_content)

# %%
clean_content
# Out:
# '<html><body><p>These days people make all sorts of public and private hand gestures to convey a wide variety of information.\xa0 Innocent though they may seem, for various reasons many of them become controversial (e.g., the sign for "OK", which has recently been classified by some organizations as a symbol of hate).</p>\n<p>These students at a university in China are making the sign of bǐxīn 比心.\xa0 According to their professor, it means "love you" or "give you my heart".</p>\n<p align="center"><a href="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin1.jpg"><img alt="" src="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin1.jpg" title="Click to embiggen" width="475"/></a><span id="more-45581"></span></p>\n<p>Here\'s the same photo with the many heart gestures outlined in red:</p>\n<p align="center"><a href="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin2.jpg"><img alt="" src="http://languagelog.ldc.upenn.edu/~bgzimmer/bixin2.jpg" title="Click to embiggen" width="475"/></a></p>\n<p
# ...

# %%
nltk.word_tokenize(clean_content)
# Out:
# ['<',
#  'html',
#  '>',
#  '<',
#  'body',
#  '>',
#  '<',
#  'p',
#  '>',
#  'These',
#  'days',
#  'people',
#  'make',
#  'all',
#  'sorts',
#  'of',
#  'public',
#  'and',
#  'private',
#  'hand',
#  'gestures',
#  'to',
#  'convey',
#  'a',
#  'wide',
#  'variety',
#  'of',
#  'information',
#  '.',
#  'Innocent',
#  'though',
#  'they',
#  'may',
#  'seem',
#  ',',
#  'for',
#  'various',
#  'reasons',
#  'many',
#  'of',
#  'them',
#  'become',
#  'controversial',
#  '(',
#  'e.g.',
#  ',',
#  'the',
#  'sign',
#  'for',
#  '``',
#  'OK',
#  "''",
#  ',',
#  'which',
#  'has',
#  'recently',
#  'been',
#  'classified',
#  'by',
#  'some',
#  'organizations',
#  'as',
#  'a',
#  'symbol',
#  'of',
#  'hate',
#  ')',
#  '.',
#  '<',
#  '/p',
#  '>',
#  '<',
#  'p',
#  '>',
#  'These',
#  'students',
#  'at',
#  'a',
#  'university',
#  'in',
#  'China',
#  'are',
#  'making',
#  'the',
#  'sign',
#  'of',
#  'bǐxīn',
#  '比心',
#  '.',
#  'According',
#  'to',
#  'their',
# ...

# %%
nltk.word_tokenize(str(BeautifulSoup(post.content[0].value)))
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python36\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file D:\Anaconda\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ['<',
#  'html',
#  '>',
#  '<',
#  'body',
#  '>',
#  '<',
#  'p',
#  '>',
#  'These',
#  'days',
#  'people',
#  'make',
#  'all',
#  'sorts',
#  'of',
#  'public',
#  'and',
#  'private',
#  'hand',
#  'gestures',
#  'to',
#  'convey',
#  'a',
#  'wide',
#  'variety',
#  'of',
#  'information',
#  '.',
#  'Innocent',
#  'though',
#  'they',
#  'may',
# ...

# %%
#reading text from local file from this code

# %%
f = open("D:\\python programs\\blogs\\document.txt")   #reading text from local file from this code

# %%
raw = f.read()

# %%
raw
# Out:
# 'Introduction\nIf you have been following Data Science / Machine Learning, you just canâ€™t miss the buzz around Deep Learning and Neural Networks. Organizations are looking for people with Deep Learning skills wherever they can. From running competitions to open sourcing projects and paying big bonuses, people are trying every possible thing to tap into this limited pool of talent.\n\nSelf driving engineers are being hunted by the big guns in automobile industry, as the industry stands on the brink of biggest disruption it faced in last few decades!\n\nIf you are excited by the prospects deep learning has to offer, but have not started your journey yet â€“ I am here to enable it. Starting with this article, I will write a series of articles on deep learning covering the popular Deep Learning libraries and their hands-on implementation.\n\nIn this article, I will introduce TensorFlow to you. After reading this article you will be able to understand application of neural networks and 
# ...

# %%
f = open("D:\\python programs\\blogs\\document.txt" , 'rU')
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
for line in f:
    print (line.strip())
# Out:
# Introduction
# If you have been following Data Science / Machine Learning, you just canâ€™t miss the buzz around Deep Learning and Neural Networks. Organizations are looking for people with Deep Learning skills wherever they can. From running competitions to open sourcing projects and paying big bonuses, people are trying every possible thing to tap into this limited pool of talent.
#
# Self driving engineers are being hunted by the big guns in automobile industry, as the industry stands on the brink of biggest disruption it faced in last few decades!
#
# If you are excited by the prospects deep learning has to offer, but have not started your journey yet â€“ I am here to enable it. Starting with this article, I will write a series of articles on deep learning covering the popular Deep Learning libraries and their hands-on implementation.
#
# ...

# %%
#reading PDF files using 3rd party library

# %%
from PyPDF2 import PdfFileReader

def extract_information(pdf_path):
    with open(pdf_path, 'rb') as f:
        pdf = PdfFileReader(f)
        information = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()

    txt = f"""
    Information about {pdf_path}: 

    Author: {information.author}
    Creator: {information.creator}
    Producer: {information.producer}
    Subject: {information.subject}
    Title: {information.title}
    Number of pages: {number_of_pages}
    """

    print(txt)
    return information

if __name__ == '__main__':
    path = 'D:\\python programs\\blogs\\statisticaltests.pdf'
    extract_information(path)
# Out:
#     Information about D:\python programs\blogs\statisticaltests.pdf:
#
#     Author: Windows User
#     Creator: Microsoft® Word 2010
#     Producer: Microsoft® Word 2010
#     Subject: None
#     Title: None
#     Number of pages: 4

# %%
from PyPDF2 import PdfFileReader

def extract_information(pdf_path):
    with open(pdf_path, 'rb') as f:
        pdf = PdfFileReader(f)
        information = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()

    txt = f"""
    Information about {pdf_path}: 

    Author: {information.author}
    Creator: {information.creator}
    Producer: {information.producer}
    Subject: {information.subject}
    Title: {information.title}
    Number of pages: {number_of_pages}
    """

    print(txt)
    return information

if __name__ == '__main__':
    path = 'D:\\python programs\\blogs\\sun.pdf'
    extract_information(path)
# Out:
#     Information about D:\python programs\blogs\sun.pdf:
#
#     Author: Windows User
#     Creator: Microsoft® Word 2010
#     Producer: Microsoft® Word 2010
#     Subject: None
#     Title: None
#     Number of pages: 58

# %%
#we can see merging of PDF in below

# %%
from PyPDF2 import PdfFileReader, PdfFileWriter

def merge_pdfs(paths, output):
    pdf_writer = PdfFileWriter()

    for path in paths:
        pdf_reader = PdfFileReader(path)
        for page in range(pdf_reader.getNumPages()):
            # Add each page to the writer object
            pdf_writer.addPage(pdf_reader.getPage(page))

    # Write out the merged PDF
    with open(output, 'wb') as out:
        pdf_writer.write(out)

if __name__ == '__main__':
    paths = ['D:\\python programs\\blogs\\statisticaltests.pdf', 'D:\\python programs\\blogs\\sun.pdf']
    merge_pdfs(paths, output='D:\\python programs\\blogs\\mergedsampletest.pdf')

# %%
#reading and operating unicode characters

# %%
path = nltk.data.find('corpora/unicode_samples/polish-lat2.txt')

# %%
import codecs

# %%
f = codecs.open(path,encoding='latin2')

# %%
for line in f:
    line = line.strip()
    print (line.encode('unicode_escape'))
# Out:
# b'Pruska Biblioteka Pa\\u0144stwowa. Jej dawne zbiory znane pod nazw\\u0105'
# b'"Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez'
# b'Niemc\\xf3w pod koniec II wojny \\u015bwiatowej na Dolny \\u015al\\u0105sk, zosta\\u0142y'
# b'odnalezione po 1945 r. na terytorium Polski. Trafi\\u0142y do Biblioteki'
# b'Jagiello\\u0144skiej w Krakowie, obejmuj\\u0105 ponad 500 tys. zabytkowych'
# b'archiwali\\xf3w, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.'

# %%
# we can see some sample regex operations

# %%
import re

# %%
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]

# %%
wordlist
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aardvark',
#  'aardwolf',
#  'aba',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abaptiston',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
# ...

# %%
[w for w in wordlist if re.search('ed$',w)]
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %%
[w for w in wordlist if re.search('^..s..d..$',w)]
# Out:
# ['absurdly',
#  'beshadow',
#  'besmudge',
#  'besodden',
#  'cassidid',
#  'cuspidal',
#  'cuspidor',
#  'cussedly',
#  'custodee',
#  'custodes',
#  'dashedly',
#  'diselder',
#  'disendow',
#  'dislodge',
#  'dismoded',
#  'disorder',
#  'ensandal',
#  'enshadow',
#  'gospodar',
#  'hospodar',
#  'hushedly',
#  'hussydom',
#  'massedly',
#  'mastodon',
#  'misandry',
#  'miserdom',
#  'misjudge',
#  'mislodge',
#  'misorder',
#  'muscadel',
#  'pashadom',
#  'resaddle',
#  'resolder',
#  'unsadden',
#  'unsaddle',
#  'unsanded',
#  'unseeded',
#  'unseldom',
#  'unshaded',
#  'unshadow',
#  'unsodden',
#  'unsolder',
#  'unsordid',
#  'unspaded',
#  'upsaddle',
#  'viscidly',
#  'wishedly']

# %%
#using regex we caan also get idea of t9 works

# %%
[w for w in wordlist if re.search('^[abc][ghi][def][pqrs]$',w)]
# Out:
# ['ager', 'bier']

# %%
# examples of regex using chat words

# %%
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))

# %%
[w for w in chat_words if re.search('^m+i+n+e+$',w)]
# Out:
# ['miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'mine',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee']

# %%
[w for w in chat_words if re.search('^[ha]+$',w)]
# Out:
# ['a',
#  'aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'ah',
#  'ahah',
#  'ahahah',
#  'ahh',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'h',
#  'ha',
#  'haaa',
#  'hah',
#  'haha',
#  'hahaaa',
#  'hahah',
#  'hahaha',
#  'hahahaa',
#  'hahahah',
#  'hahahaha',
#  'hahahahaaa',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hahahahahahahahahahahahahahahaha',
#  'hahahhahah',
#  'hahhahahaha']

# %%
wsg = sorted(set(nltk.corpus.treebank.words()))

# %%
[w for w in wsg if re.search('^[0-9]+\.[0-9]+$',w)]
# Out:
# ['0.0085',
#  '0.05',
#  '0.1',
#  '0.16',
#  '0.2',
#  '0.25',
#  '0.28',
#  '0.3',
#  '0.4',
#  '0.5',
#  '0.50',
#  '0.54',
#  '0.56',
#  '0.60',
#  '0.7',
#  '0.82',
#  '0.84',
#  '0.9',
#  '0.95',
#  '0.99',
#  '1.01',
#  '1.1',
#  '1.125',
#  '1.14',
#  '1.1650',
#  '1.17',
#  '1.18',
#  '1.19',
#  '1.2',
#  '1.20',
#  '1.24',
#  '1.25',
#  '1.26',
#  '1.28',
#  '1.35',
#  '1.39',
#  '1.4',
#  '1.457',
#  '1.46',
#  '1.49',
#  '1.5',
#  '1.50',
#  '1.55',
#  '1.56',
#  '1.5755',
#  '1.5805',
#  '1.6',
#  '1.61',
#  '1.637',
#  '1.64',
#  '1.65',
#  '1.7',
#  '1.75',
#  '1.76',
#  '1.8',
#  '1.82',
#  '1.8415',
#  '1.85',
#  '1.8500',
#  '1.9',
#  '1.916',
#  '1.92',
#  '10.19',
#  '10.2',
#  '10.5',
#  '107.03',
#  '107.9',
#  '109.73',
#  '11.10',
#  '11.5',
#  '11.57',
#  '11.6',
#  '11.72',
#  '11.95',
#  '112.9',
#  '113.2',
#  '116.3',
#  '116.4',
#  '116.7',
#  '116.9',
#  '118.6',
#  '12.09',
#  '12.5',
#  '12.52',
#  '12.68',
#  '12.7',
#  '12.82',
#  '12.97',
# ...

# %%
[w for w in wsg if re.search('^[A-Z]+\$$',w)]
# Out:
# ['C$', 'US$']

# %%
[w for w in wsg if re.search('^[0-9]{4}$',w)]
# Out:
# ['1614',
#  '1637',
#  '1787',
#  '1901',
#  '1903',
#  '1917',
#  '1925',
#  '1929',
#  '1933',
#  '1934',
#  '1948',
#  '1953',
#  '1955',
#  '1956',
#  '1961',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1975',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2005',
#  '2009',
#  '2017',
#  '2019',
#  '2029',
#  '3057',
#  '8300']

# %%
[w for w in wsg if re.search('^[0-9]+-[a-z]{3,5}$',w)]
# Out:
# ['10-day',
#  '10-lap',
#  '10-year',
#  '100-share',
#  '12-point',
#  '12-year',
#  '14-hour',
#  '15-day',
#  '150-point',
#  '190-point',
#  '20-point',
#  '20-stock',
#  '21-month',
#  '237-seat',
#  '240-page',
#  '27-year',
#  '30-day',
#  '30-point',
#  '30-share',
#  '30-year',
#  '300-day',
#  '36-day',
#  '36-store',
#  '42-year',
#  '50-state',
#  '500-stock',
#  '52-week',
#  '69-point',
#  '84-month',
#  '87-store',
#  '90-day']

# %%
[w for w in wsg if re.search('(ed|ing)$',w)]
# Out:
# ['62%-owned',
#  'Absorbed',
#  'According',
#  'Adopting',
#  'Advanced',
#  'Advancing',
#  'Alfred',
#  'Allied',
#  'Annualized',
#  'Anything',
#  'Arbitrage-related',
#  'Arbitraging',
#  'Asked',
#  'Assuming',
#  'Atlanta-based',
#  'Baking',
#  'Banking',
#  'Beginning',
#  'Beijing',
#  'Being',
#  'Bermuda-based',
#  'Betting',
#  'Boeing',
#  'Broadcasting',
#  'Bucking',
#  'Buying',
#  'Calif.-based',
#  'Change-ringing',
#  'Citing',
#  'Concerned',
#  'Confronted',
#  'Conn.based',
#  'Consolidated',
#  'Continued',
#  'Continuing',
#  'Declining',
#  'Defending',
#  'Depending',
#  'Designated',
#  'Determining',
#  'Developed',
#  'Died',
#  'During',
#  'Encouraged',
#  'Encouraging',
#  'English-speaking',
#  'Estimated',
#  'Everything',
#  'Excluding',
#  'Exxon-owned',
#  'Faulding',
#  'Fed',
#  'Feeding',
#  'Filling',
#  'Filmed',
#  'Financing',
#  'Following',
#  'Founded',
#  'Fracturing',
#  'Francisco-based',
#  'Fred',
#  'Funded',
#  'Funding',
# ...

# %%
word = 'supercalifragilisticexpalidicious'

# %%
re.findall(r'[aeiou]',word)
# Out:
# ['u', 'e', 'a', 'i', 'a', 'i', 'i', 'i', 'e', 'a', 'i', 'i', 'i', 'o', 'u']

# %%
len(re.findall(r'[aeiou]',word))
# Out:
# 15

# %%
rotokas_words = nltk.corpus.toolbox.words('rotokas.dic')

# %%
cvs = [cv for w in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]',w)]

# %%
cfd = nltk.ConditionalFreqDist(cvs)

# %%
cfd
# Out:
# ConditionalFreqDist(nltk.probability.FreqDist,
#                     {'k': FreqDist({'a': 418,
#                                'e': 148,
#                                'i': 94,
#                                'o': 420,
#                                'u': 173}),
#                      'p': FreqDist({'a': 83,
#                                'e': 31,
#                                'i': 105,
#                                'o': 34,
#                                'u': 51}),
#                      'r': FreqDist({'a': 187,
#                                'e': 63,
#                                'i': 84,
#                                'o': 89,
#                                'u': 79}),
#                      's': FreqDist({'i': 100, 'o': 2, 'u': 1}),
#                      't': FreqDist({'a': 47, 'e': 8, 'o': 148, 'u': 37}),
#                      'v': FreqDist({'a': 93,
#                                'e': 27,
#                                'i': 105,
# ...

# %%
cfd.tabulate()
# Out:
#     a   e   i   o   u
# k 418 148  94 420 173
# p  83  31 105  34  51
# r 187  63  84  89  79
# s   0   0 100   2   1
# t  47   8   0 148  37
# v  93  27 105  48  49

# %%
# we can see creating sample index

# %%
cv_word_pairs = [(cv,w) for w in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]',w)]

# %%
cv_index = nltk.Index(cv_word_pairs)

# %%
cv_index['su']
# Out:
# ['kasuari']

# %%
cv_index['po']
# Out:
# ['kaapo',
#  'kaapopato',
#  'kaipori',
#  'kaiporipie',
#  'kaiporivira',
#  'kapo',
#  'kapoa',
#  'kapokao',
#  'kapokapo',
#  'kapokapo',
#  'kapokapoa',
#  'kapokapoa',
#  'kapokapora',
#  'kapokapora',
#  'kapokaporo',
#  'kapokaporo',
#  'kapokari',
#  'kapokarito',
#  'kapokoa',
#  'kapoo',
#  'kapooto',
#  'kapoovira',
#  'kapopaa',
#  'kaporo',
#  'kaporo',
#  'kaporopa',
#  'kaporoto',
#  'kapoto',
#  'karokaropo',
#  'karopo',
#  'kepo',
#  'kepoi',
#  'keposi',
#  'kepoto']

# %%
# we can see the stemming example in below code .

# example the word laptops , laptop refers to same object , stemming refers to reduce the ending term

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government.  Supreme executive power derives from a mandate from the masses, not from some farcical aquatic ceremony."""

# %%
def stem(word):
    regexp = r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
    stem,suffix = re.findall(regexp,word)[0]
    return stem

# %%
tokens = nltk.word_tokenize(raw)

# %%
[stem(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'ly',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'i',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'Supreme',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %%
#lemmatization  also refers to same as stemming but this takes cares of dictionary and words will be sliced as per dictionary terms

# %%
raw
# Out:
# 'DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government.  Supreme executive power derives from a mandate from the masses, not from some farcical aquatic ceremony.'

# %%
tokens
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'lying',
#  'in',
#  'ponds',
#  'distributing',
#  'swords',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'masses',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %%
porter = nltk.PorterStemmer()

# %%
lancaster = nltk.LancasterStemmer()

# %%
[porter.stem(t) for t in tokens]
# Out:
# ['denni',
#  ':',
#  'listen',
#  ',',
#  'strang',
#  'women',
#  'lie',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandat',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcic',
#  'aquat',
#  'ceremoni',
#  '.']

# %%
[lancaster.stem(t) for t in tokens]
# Out:
# ['den',
#  ':',
#  'list',
#  ',',
#  'strange',
#  'wom',
#  'lying',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'bas',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'pow',
#  'der',
#  'from',
#  'a',
#  'mand',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'som',
#  'farc',
#  'aqu',
#  'ceremony',
#  '.']

# %%
# we can see that distribution is reduced to 'distribut' like wise lemmatization produces meaningful reduction

# %%
wnl = nltk.WordNetLemmatizer()

# %%
[wnl.lemmatize(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'woman',
#  'lying',
#  'in',
#  'pond',
#  'distributing',
#  'sword',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %%
#we can see meaningful deduction of suffixes but this takes time and performance compromise can be seen

# %%
#split operation examples .

# %%
re.split(r'[\t\n]+',raw)
# Out:
# ['DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government.  Supreme executive power derives from a mandate from the masses, not from some farcical aquatic ceremony.']

# %%
re.split(r'\wt',raw)
# Out:
# ['DENNIS: Li',
#  'en, ',
#  'range women lying in ponds di',
#  'rib',
#  'ing swords is no basis for a sy',
#  'em of governme',
#  '.  Supreme exec',
#  'ive power derives from a mand',
#  'e from the masses, n',
#  ' from some farcical aqu',
#  'ic ceremony.']

# %%
#writing ressult to output file

# %%
output_file = open('D:\\python programs\\blogs\\outputsample.txt','w')

# %%
words = set(nltk.corpus.genesis.words('english-kjv.txt'))

# %%
for word in sorted(words):
    output_file.write(word + '\n')

# %%
#end of file and credits NLP with python O'Reilly
